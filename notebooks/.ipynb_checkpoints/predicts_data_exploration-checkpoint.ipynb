# %% [markdown]
# # Bayesian biodiversity: PREDICTS data exploration

# %% [markdown]
# ### TODO
# - Filtering of data
# - Color palettes
# - Number formatting below 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from typing import List
import geopandas as geopd
import polars as pl

# from shapely.geometry import Point
from matplotlib.ticker import FuncFormatter, MaxNLocator
import time
import scipy

# %%
# Load black for formatting
import jupyter_black

jupyter_black.load()

# Adjust display settings for pandas
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", 100)
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
sns.set_style("ticks")
plt.rc("figure", titlesize="medium")
plt.rc("font", size=10, family="serif")
plt.rc("axes", titlesize="medium")
plt.rc("text", usetex=True)
plt.rc("text.latex", preamble=r"\usepackage{amsmath}\usepackage{amssymb}")

# %%
# Load the complete data set
# The first sections use pandas functions, so we load it as a pd dataframe
df_predicts = pd.read_csv("../../data/PREDICTS/merged_data.csv")
# Out:
# /var/folders/pd/qpp_vpcn3wv209_68c5q1_r80000gn/T/ipykernel_57365/4292107368.py:3: DtypeWarning: Columns (5,7,23,24,36,64) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_predicts = pd.read_csv("../../data/PREDICTS/merged_data.csv")

# %%
df_predicts.shape
# Out:
# (4318808, 68)

# %%
df_predicts.head()
# Out:
#      _id           Source_ID             Reference  Study_number  \
# 0  26004  AD1_2008__Billeter  Billeter et al. 2008             8
# 1  26006  AD1_2008__Billeter  Billeter et al. 2008             8
# 2  26024  AD1_2008__Billeter  Billeter et al. 2008             8
# 3  26031  AD1_2008__Billeter  Billeter et al. 2008             8
# 4  26032  AD1_2008__Billeter  Billeter et al. 2008             8
#
#                 Study_name Block  Site_number Site_name                    SS  \
# 0  Greenveins2001_France02    F2           32      F2.P  AD1_2008__Billeter 8
# 1  Greenveins2001_France02    F2           32      F2.P  AD1_2008__Billeter 8
# 2  Greenveins2001_France02    F3           33      F3.A  AD1_2008__Billeter 8
# 3  Greenveins2001_France02    F3           33      F3.A  AD1_2008__Billeter 8
# 4  Greenveins2001_France02    F3           33      F3.A  AD1_2008__Billeter 8
#
#                        SSS                      SSB  \
# 0  AD1_2008__Billeter 8 32  AD1_2008__Billeter 8 F2
# 1  AD1_2008__Billeter 8 32  AD1_2008__Billeter 8 F2
# 2  AD1_2008__Billeter 8 33  AD1_2008__Billeter 8 F3
# 3  AD1_2008__Billeter 8 33  AD1_2008__Billeter 8 F3
# 4  AD1_2008__Billeter 8 33  AD1_2008__Billeter 8 F3
#
#                          SSBS  Longitude   Latitude  \
# 0  AD1_2008__Billeter 8 F2 32  -1.590365  48.472153
# 1  AD1_2008__Billeter 8 F2 32  -1.590365  48.472153
# 2  AD1_2008__Billeter 8 F3 33  -1.610663  48.540593
# 3  AD1_2008__Billeter 8 F3 33  -1.610663  48.540593
# 4  AD1_2008__Billeter 8 F3 33  -1.610663  48.540593
#
#                  Coordinates_method Country  Country_distance_metres  \
# 0  Direct from publication / author  France                      0.0
# 1  Direct from publication / author  France                      0.0
# 2  Direct from publication / author  France                      0.0
# 3  Direct from publication / author  France                      0.0
# 4  Direct from publication / author  France                      0.0
#
#   UN_region    UN_subregion       Realm                                Biome  \
# 0    Europe  Western Europe  Palearctic  Temperate Broadleaf & Mixed Forests
# 1    Europe  Western Europe  Palearctic  Temperate Broadleaf & Mixed Forests
# 2    Europe  Western Europe  Palearctic  Temperate Broadleaf & Mixed Forests
# 3    Europe  Western Europe  Palearctic  Temperate Broadleaf & Mixed Forests
# 4    Europe  Western Europe  Palearctic  Temperate Broadleaf & Mixed Forests
#
#                 Ecoregion  Ecoregion_distance_metres Wilderness_area Hotspot  \
# 0  Atlantic Mixed Forests                        0.0             NaN     NaN
# 1  Atlantic Mixed Forests                        0.0             NaN     NaN
# 2  Atlantic Mixed Forests                        0.0             NaN     NaN
# 3  Atlantic Mixed Forests                        0.0             NaN     NaN
# 4  Atlantic Mixed Forests                        0.0             NaN     NaN
#
#   Study_common_taxon Rank_of_study_common_taxon Sample_start_earliest  \
# 0        Hymenoptera                      Order            2002-01-01
# 1        Hymenoptera                      Order            2002-01-01
# 2        Hymenoptera                      Order            2002-01-01
# 3        Hymenoptera                      Order            2002-01-01
# 4        Hymenoptera                      Order            2002-01-01
#
#   Sample_end_latest Sample_midpoint Sample_date_resolution Sampling_method  \
# 0        2002-12-31      2002-07-02                   year     flight trap
# 1        2002-12-31      2002-07-02                   year     flight trap
# 2        2002-12-31      2002-07-02                   year     flight trap
# 3        2002-12-31      2002-07-02                   year     flight trap
# 4        2002-12-31      2002-07-02                   year     flight trap
#
#    Sampling_effort  Rescaled_sampling_effort Sampling_effort_unit  \
# 0              5.0                       1.0                 week
# 1              5.0                       1.0                 week
# 2              5.0                       1.0                 week
# 3              5.0                       1.0                 week
# 4              5.0                       1.0                 week
#
#    Max_linear_extent_metres  \
# 0                  1414.214
# 1                  1414.214
# 2                  1414.214
# 3                  1414.214
# 4                  1414.214
#
#                                     Transect_details                   Taxon  \
# 0  Ecotone between a Green-veins habitat and an a...      Lasioglossum morio
# 1  Ecotone between a Green-veins habitat and an a...  Lasioglossum pauxillum
# 2  Ecotone between a Green-veins habitat and an a...         Andrena helvola
# 3  Ecotone between a Green-veins habitat and an a...         Andrena ovatula
# 4  Ecotone between a Green-veins habitat and an a...                 Andrena
#
#    Taxon_number      Taxon_name_entered             Parsed_name  \
# 0            49      Lasioglossum morio      Lasioglossum morio
# 1            51  Lasioglossum pauxillum  Lasioglossum pauxillum
# 2            11         Andrena helvola         Andrena helvola
# 3            18         Andrena ovatula         Andrena ovatula
# 4            19       Andrena spinigera       Andrena spinigera
#
#       Best_guess_binomial      COL_ID   Kingdom      Phylum    Class  \
# 0      Lasioglossum morio   6967008.0  Animalia  Arthropoda  Insecta
# 1  Lasioglossum pauxillum   6967187.0  Animalia  Arthropoda  Insecta
# 2         Andrena helvola   6960605.0  Animalia  Arthropoda  Insecta
# 3         Andrena ovatula   6960904.0  Animalia  Arthropoda  Insecta
# 4       Andrena spinigera  13049592.0  Animalia  Arthropoda  Insecta
#
#          Order      Family         Genus    Species Higher_taxon  \
# 0  Hymenoptera  Halictidae  Lasioglossum      morio  Hymenoptera
# 1  Hymenoptera  Halictidae  Lasioglossum  pauxillum  Hymenoptera
# 2  Hymenoptera  Andrenidae       Andrena    helvola  Hymenoptera
# 3  Hymenoptera  Andrenidae       Andrena    ovatula  Hymenoptera
# 4  Hymenoptera  Andrenidae       Andrena        NaN  Hymenoptera
#
#                        Indication    Name_status     Rank  \
# 0  Hymenoptera: Apidae sensu lato  accepted name  Species
# 1  Hymenoptera: Apidae sensu lato  accepted name  Species
# 2  Hymenoptera: Apidae sensu lato  accepted name  Species
# 3  Hymenoptera: Apidae sensu lato  accepted name  Species
# 4  Hymenoptera: Apidae sensu lato  accepted name    Genus
#
#   Diversity_metric_type Diversity_metric  \
# 0             Abundance        abundance
# 1             Abundance        abundance
# 2             Abundance        abundance
# 3             Abundance        abundance
# 4             Abundance        abundance
#
#    Diversity_metric_is_effort_sensitive  \
# 0                                  True
# 1                                  True
# 2                                  True
# 3                                  True
# 4                                  True
#
#    Diversity_metric_is_suitable_for_Chao Diversity_metric_unit  Measurement  \
# 0                                   True           individuals          0.0
# 1                                   True           individuals          0.0
# 2                                   True           individuals          0.0
# 3                                   True           individuals          0.0
# 4                                   True           individuals          0.0
#
#    Effort_corrected_measurement Predominant_land_use  \
# 0                           0.0             Cropland
# 1                           0.0             Cropland
# 2                           0.0             Cropland
# 3                           0.0             Cropland
# 4                           0.0             Cropland
#
#     Source_for_predominant_land_use Use_intensity Habitat_as_described  \
# 0  Direct from publication / author   Minimal use                  NaN
# 1  Direct from publication / author   Minimal use                  NaN
# 2  Direct from publication / author     Light use                  NaN
# 3  Direct from publication / author     Light use                  NaN
# 4  Direct from publication / author     Light use                  NaN
#
#    Habitat_patch_area_square_metres  Km_to_nearest_edge_of_habitat  \
# 0                               NaN                            NaN
# 1                               NaN                            NaN
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 4                               NaN                            NaN
#
#    Years_since_fragmentation_or_conversion
# 0                                     13.5
# 1                                     13.5
# 2                                     63.5
# 3                                     63.5
# 4                                     63.5

# %%
df_block_na = df_predicts[df_predicts["Block"].isna()]

# %%
df_block_na.head(10)
# Out:
#        _id          Source_ID            Reference  Study_number  \
# 18616    2     AD1_2001__Liow     Liow et al. 2001             1
# 18617    3     AD1_2001__Liow     Liow et al. 2001             1
# 18618    7     AD1_2001__Liow     Liow et al. 2001             2
# 18619   16     AD1_2001__Liow     Liow et al. 2001             4
# 18620   18  AD1_2004__Darvill  Darvill et al. 2004             1
# 18621   22  AD1_2004__Darvill  Darvill et al. 2004             1
# 18622   29  AD1_2004__Darvill  Darvill et al. 2004             1
# 18623   41  AD1_2004__Darvill  Darvill et al. 2004             1
# 18624   44  AD1_2004__Darvill  Darvill et al. 2004             1
# 18625   52  AD1_2004__Darvill  Darvill et al. 2004             1
#
#                       Study_name Block  Site_number   Site_name  \
# 18616        Singapore_abundance   NaN            2          MC
# 18617        Singapore_abundance   NaN            3          NS
# 18618  Singapore_speciesrichness   NaN            2          MC
# 18619   Malaysia_speciesrichness   NaN            3         UMP
# 18620       Darvill2004_transect   NaN            1   Darvill_1
# 18621       Darvill2004_transect   NaN            2   Darvill_2
# 18622       Darvill2004_transect   NaN            5   Darvill_5
# 18623       Darvill2004_transect   NaN            9   Darvill_9
# 18624       Darvill2004_transect   NaN           10  Darvill_10
# 18625       Darvill2004_transect   NaN           12  Darvill_12
#
#                         SS                     SSS                   SSB  \
# 18616     AD1_2001__Liow 1      AD1_2001__Liow 1 2     AD1_2001__Liow 1
# 18617     AD1_2001__Liow 1      AD1_2001__Liow 1 3     AD1_2001__Liow 1
# 18618     AD1_2001__Liow 2      AD1_2001__Liow 2 2     AD1_2001__Liow 2
# 18619     AD1_2001__Liow 4      AD1_2001__Liow 4 3     AD1_2001__Liow 4
# 18620  AD1_2004__Darvill 1   AD1_2004__Darvill 1 1  AD1_2004__Darvill 1
# 18621  AD1_2004__Darvill 1   AD1_2004__Darvill 1 2  AD1_2004__Darvill 1
# 18622  AD1_2004__Darvill 1   AD1_2004__Darvill 1 5  AD1_2004__Darvill 1
# 18623  AD1_2004__Darvill 1   AD1_2004__Darvill 1 9  AD1_2004__Darvill 1
# 18624  AD1_2004__Darvill 1  AD1_2004__Darvill 1 10  AD1_2004__Darvill 1
# 18625  AD1_2004__Darvill 1  AD1_2004__Darvill 1 12  AD1_2004__Darvill 1
#
#                           SSBS   Longitude   Latitude  \
# 18616      AD1_2001__Liow 1  2  103.808056   1.354722
# 18617      AD1_2001__Liow 1  3  103.811667   1.394722
# 18618      AD1_2001__Liow 2  2  103.808056   1.354722
# 18619      AD1_2001__Liow 4  3  103.466667   1.566667
# 18620   AD1_2004__Darvill 1  1   -1.537222  50.953333
# 18621   AD1_2004__Darvill 1  2   -1.547421  50.956356
# 18622   AD1_2004__Darvill 1  5   -1.571283  50.963722
# 18623   AD1_2004__Darvill 1  9   -1.600717  50.973455
# 18624  AD1_2004__Darvill 1  10   -1.608446  50.975776
# 18625  AD1_2004__Darvill 1  12   -1.623728  50.982033
#
#                      Coordinates_method         Country  \
# 18616                     Georeferenced       Singapore
# 18617                     Georeferenced       Singapore
# 18618                     Georeferenced       Singapore
# 18619  Direct from publication / author        Malaysia
# 18620  Direct from publication / author  United Kingdom
# 18621                     Georeferenced  United Kingdom
# 18622                     Georeferenced  United Kingdom
# 18623                     Georeferenced  United Kingdom
# 18624                     Georeferenced  United Kingdom
# 18625                     Georeferenced  United Kingdom
#
#        Country_distance_metres UN_region        UN_subregion       Realm  \
# 18616                      0.0      Asia  South-Eastern Asia  Indo-Malay
# 18617                      0.0      Asia  South-Eastern Asia  Indo-Malay
# 18618                      0.0      Asia  South-Eastern Asia  Indo-Malay
# 18619                      0.0      Asia  South-Eastern Asia  Indo-Malay
# 18620                      0.0    Europe     Northern Europe  Palearctic
# 18621                      0.0    Europe     Northern Europe  Palearctic
# 18622                      0.0    Europe     Northern Europe  Palearctic
# 18623                      0.0    Europe     Northern Europe  Palearctic
# 18624                      0.0    Europe     Northern Europe  Palearctic
# 18625                      0.0    Europe     Northern Europe  Palearctic
#
#                                                 Biome  \
# 18616  Tropical & Subtropical Moist Broadleaf Forests
# 18617  Tropical & Subtropical Moist Broadleaf Forests
# 18618  Tropical & Subtropical Moist Broadleaf Forests
# 18619  Tropical & Subtropical Moist Broadleaf Forests
# 18620             Temperate Broadleaf & Mixed Forests
# 18621             Temperate Broadleaf & Mixed Forests
# 18622             Temperate Broadleaf & Mixed Forests
# 18623             Temperate Broadleaf & Mixed Forests
# 18624             Temperate Broadleaf & Mixed Forests
# 18625             Temperate Broadleaf & Mixed Forests
#
#                                Ecoregion  Ecoregion_distance_metres  \
# 18616  Peninsular Malaysian Rain Forests                        0.0
# 18617  Peninsular Malaysian Rain Forests                        0.0
# 18618  Peninsular Malaysian Rain Forests                        0.0
# 18619  Peninsular Malaysian Rain Forests                        0.0
# 18620     English Lowlands Beech Forests                        0.0
# 18621     English Lowlands Beech Forests                        0.0
# 18622     English Lowlands Beech Forests                        0.0
# 18623     English Lowlands Beech Forests                        0.0
# 18624     English Lowlands Beech Forests                        0.0
# 18625     English Lowlands Beech Forests                        0.0
#
#       Wilderness_area    Hotspot Study_common_taxon  \
# 18616             NaN  Sundaland             Apidae
# 18617             NaN  Sundaland             Apidae
# 18618             NaN  Sundaland             Apidae
# 18619             NaN  Sundaland             Apidae
# 18620             NaN        NaN             Bombus
# 18621             NaN        NaN             Bombus
# 18622             NaN        NaN             Bombus
# 18623             NaN        NaN             Bombus
# 18624             NaN        NaN             Bombus
# 18625             NaN        NaN             Bombus
#
#       Rank_of_study_common_taxon Sample_start_earliest Sample_end_latest  \
# 18616                     Family            1999-02-24        1999-06-24
# 18617                     Family            1999-03-16        1999-07-08
# 18618                     Family            1999-02-24        1999-06-24
# 18619                     Family            1999-03-12        1999-07-22
# 18620                      Genus            2001-07-01        2001-07-31
# 18621                      Genus            2001-07-01        2001-07-31
# 18622                      Genus            2001-07-01        2001-07-31
# 18623                      Genus            2001-07-01        2001-07-31
# 18624                      Genus            2001-07-01        2001-07-31
# 18625                      Genus            2001-07-01        2001-07-31
#
#       Sample_midpoint Sample_date_resolution       Sampling_method  \
# 18616      1999-04-25                    day  transects with baits
# 18617      1999-05-12                    day  transects with baits
# 18618      1999-04-25                    day  transects with baits
# 18619      1999-05-17                    day  transects with baits
# 18620      2001-07-16                  month   specimen collection
# 18621      2001-07-16                  month   specimen collection
# 18622      2001-07-16                  month   specimen collection
# 18623      2001-07-16                  month   specimen collection
# 18624      2001-07-16                  month   specimen collection
# 18625      2001-07-16                  month   specimen collection
#
#        Sampling_effort  Rescaled_sampling_effort Sampling_effort_unit  \
# 18616             30.0                       1.0                 trap
# 18617             30.0                       1.0                 trap
# 18618             30.0                       1.0                 trap
# 18619             30.0                       1.0                 trap
# 18620              2.0                       1.0                 hour
# 18621              2.0                       1.0                 hour
# 18622              2.0                       1.0                 hour
# 18623              2.0                       1.0                 hour
# 18624              2.0                       1.0                 hour
# 18625              2.0                       1.0                 hour
#
#        Max_linear_extent_metres Transect_details              Taxon  \
# 18616                    3000.0              NaN             Apidae
# 18617                    3000.0              NaN             Apidae
# 18618                    3000.0              NaN             Apidae
# 18619                    3000.0              NaN             Apidae
# 18620                     100.0              NaN  Bombus terrestris
# 18621                     100.0              NaN     Bombus lucorum
# 18622                     100.0              NaN   Bombus pascuorum
# 18623                     100.0              NaN   Bombus pascuorum
# 18624                     100.0              NaN   Bombus pascuorum
# 18625                     100.0              NaN     Bombus lucorum
#
#        Taxon_number  Taxon_name_entered        Parsed_name  \
# 18616             1                Bees               Bees
# 18617             1                Bees               Bees
# 18618             1                Bees               Bees
# 18619             1                Bees               Bees
# 18620             2   Bombus terrestris  Bombus terrestris
# 18621             3  Bombus lucorum (?)     Bombus lucorum
# 18622             1    Bombus pascuorum   Bombus pascuorum
# 18623             1    Bombus pascuorum   Bombus pascuorum
# 18624             1    Bombus pascuorum   Bombus pascuorum
# 18625             3  Bombus lucorum (?)     Bombus lucorum
#
#       Best_guess_binomial      COL_ID   Kingdom      Phylum    Class  \
# 18616                 NaN  13025340.0  Animalia  Arthropoda  Insecta
# 18617                 NaN  13025340.0  Animalia  Arthropoda  Insecta
# 18618                 NaN  13025340.0  Animalia  Arthropoda  Insecta
# 18619                 NaN  13025340.0  Animalia  Arthropoda  Insecta
# 18620   Bombus terrestris   6931931.0  Animalia  Arthropoda  Insecta
# 18621      Bombus lucorum   6931904.0  Animalia  Arthropoda  Insecta
# 18622    Bombus pascuorum   6932064.0  Animalia  Arthropoda  Insecta
# 18623    Bombus pascuorum   6932064.0  Animalia  Arthropoda  Insecta
# 18624    Bombus pascuorum   6932064.0  Animalia  Arthropoda  Insecta
# 18625      Bombus lucorum   6931904.0  Animalia  Arthropoda  Insecta
#
#              Order  Family   Genus     Species Higher_taxon  \
# 18616  Hymenoptera  Apidae     NaN         NaN  Hymenoptera
# 18617  Hymenoptera  Apidae     NaN         NaN  Hymenoptera
# 18618  Hymenoptera  Apidae     NaN         NaN  Hymenoptera
# 18619  Hymenoptera  Apidae     NaN         NaN  Hymenoptera
# 18620  Hymenoptera  Apidae  Bombus  terrestris  Hymenoptera
# 18621  Hymenoptera  Apidae  Bombus     lucorum  Hymenoptera
# 18622  Hymenoptera  Apidae  Bombus   pascuorum  Hymenoptera
# 18623  Hymenoptera  Apidae  Bombus   pascuorum  Hymenoptera
# 18624  Hymenoptera  Apidae  Bombus   pascuorum  Hymenoptera
# 18625  Hymenoptera  Apidae  Bombus     lucorum  Hymenoptera
#
#                            Indication    Name_status     Rank  \
# 18616             Hymenoptera: Apidae  accepted name   Family
# 18617             Hymenoptera: Apidae  accepted name   Family
# 18618             Hymenoptera: Apidae  accepted name   Family
# 18619             Hymenoptera: Apidae  accepted name   Family
# 18620  Hymenoptera: Apidae sensu lato  accepted name  Species
# 18621  Hymenoptera: Apidae sensu lato  accepted name  Species
# 18622  Hymenoptera: Apidae sensu lato  accepted name  Species
# 18623  Hymenoptera: Apidae sensu lato  accepted name  Species
# 18624  Hymenoptera: Apidae sensu lato  accepted name  Species
# 18625  Hymenoptera: Apidae sensu lato  accepted name  Species
#
#       Diversity_metric_type  Diversity_metric  \
# 18616             Abundance         abundance
# 18617             Abundance         abundance
# 18618      Species richness  species richness
# 18619      Species richness  species richness
# 18620             Abundance         abundance
# 18621             Abundance         abundance
# 18622             Abundance         abundance
# 18623             Abundance         abundance
# 18624             Abundance         abundance
# 18625             Abundance         abundance
#
#        Diversity_metric_is_effort_sensitive  \
# 18616                                  True
# 18617                                  True
# 18618                                 False
# 18619                                 False
# 18620                                  True
# 18621                                  True
# 18622                                  True
# 18623                                  True
# 18624                                  True
# 18625                                  True
#
#        Diversity_metric_is_suitable_for_Chao Diversity_metric_unit  \
# 18616                                   True           individuals
# 18617                                   True           individuals
# 18618                                  False     number of species
# 18619                                  False     number of species
# 18620                                   True           individuals
# 18621                                   True           individuals
# 18622                                   True           individuals
# 18623                                   True           individuals
# 18624                                   True           individuals
# 18625                                   True           individuals
#
#        Measurement  Effort_corrected_measurement  \
# 18616        242.0                         242.0
# 18617        232.0                         232.0
# 18618         22.0                          22.0
# 18619         17.0                          17.0
# 18620         13.0                          13.0
# 18621          2.0                           2.0
# 18622         30.0                          30.0
# 18623         19.0                          19.0
# 18624         14.0                          14.0
# 18625          4.0                           4.0
#
#                            Predominant_land_use  \
# 18616               Mature secondary vegetation
# 18617               Mature secondary vegetation
# 18618               Mature secondary vegetation
# 18619                         Plantation forest
# 18620                                  Cropland
# 18621                                  Cropland
# 18622                                  Cropland
# 18623  Secondary vegetation (indeterminate age)
# 18624                                  Cropland
# 18625                                  Cropland
#
#         Source_for_predominant_land_use  Use_intensity  \
# 18616  Direct from publication / author  Cannot decide
# 18617  Direct from publication / author  Cannot decide
# 18618  Direct from publication / author  Cannot decide
# 18619  Direct from publication / author  Cannot decide
# 18620  Direct from publication / author      Light use
# 18621  Direct from publication / author      Light use
# 18622  Direct from publication / author      Light use
# 18623  Direct from publication / author    Minimal use
# 18624  Direct from publication / author      Light use
# 18625  Direct from publication / author      Light use
#
#                                     Habitat_as_described  \
# 18616  Secondary forest with primary patches, surroun...
# 18617  Secondary forest with primary patches, surroun...
# 18618  Secondary forest with primary patches, surroun...
# 18619  Uniform oil palm stand surrounded by pineapple...
# 18620                                     Mixed farmland
# 18621                                     Mixed farmland
# 18622                                     Mixed farmland
# 18623                                           Woodland
# 18624                                     Mixed farmland
# 18625                                     Mixed farmland
#
#        Habitat_patch_area_square_metres  Km_to_nearest_edge_of_habitat  \
# 18616                         5210000.0                            NaN
# 18617                         7946000.0                            NaN
# 18618                         5210000.0                            NaN
# 18619                        21056000.0                            NaN
# 18620                               NaN                            NaN
# 18621                               NaN                            NaN
# 18622                               NaN                            NaN
# 18623                               NaN                            NaN
# 18624                               NaN                            NaN
# 18625                               NaN                            NaN
#
#        Years_since_fragmentation_or_conversion
# 18616                                     70.0
# 18617                                     70.0
# 18618                                     70.0
# 18619                                     53.0
# 18620                                      NaN
# 18621                                      NaN
# 18622                                      NaN
# 18623                                      NaN
# 18624                                      NaN
# 18625                                      NaN

# %% [markdown]
# ## Basic data inspection
#
# ### Data scope and coverage

# %%
# List with relevant information to display
labels = ["sampling locations", "countries", "species", "studies"]
columns = ["SSS", "Country", "Taxon_name_entered", "SS"]

# Print stats for each relevant column
print(f"Number of observations: {df_predicts.shape[0]:,}")
for label, column in zip(labels, columns):
    count = df_predicts[column].nunique()
    print(f"Number of {label}: {count:,}")
# Out:
# Number of observations: 4,318,808
# Number of sampling locations: 35,736
# Number of countries: 101
# Number of species: 53,925
# Number of studies: 817

# %% [markdown]
# ### Proportion of missing values

# %%
# Calculate the % of missing values per column
round(df_predicts.isna().sum() / df_predicts.isna().count(), 3) * 100
# Out:
# _id                                         0.0
# Source_ID                                   0.0
# Reference                                   0.0
# Study_number                                0.0
# Study_name                                  0.0
# Block                                      47.1
# Site_number                                 0.0
# Site_name                                   0.0
# SS                                          0.0
# SSS                                         0.0
# SSB                                         0.0
# SSBS                                        0.0
# Longitude                                   0.0
# Latitude                                    0.0
# Coordinates_method                          0.0
# Country                                     0.0
# Country_distance_metres                     0.0
# UN_region                                   0.0
# UN_subregion                                0.0
# Realm                                       0.0
# Biome                                       0.0
# Ecoregion                                   0.0
# Ecoregion_distance_metres                   0.0
# Wilderness_area                            97.3
# Hotspot                                    50.4
# Study_common_taxon                          1.3
# Rank_of_study_common_taxon                  1.3
# Sample_start_earliest                       0.0
# Sample_end_latest                           0.0
# Sample_midpoint                             0.0
# Sample_date_resolution                      0.0
# Sampling_method                             0.0
# Sampling_effort                             0.2
# Rescaled_sampling_effort                    0.0
# Sampling_effort_unit                        0.0
# Max_linear_extent_metres                   13.1
# Transect_details                           96.0
# Taxon                                       0.0
# Taxon_number                                0.0
# Taxon_name_entered                          0.0
# Parsed_name                                 0.1
# Best_guess_binomial                        20.6
# COL_ID                                      0.0
# Kingdom                                     0.0
# Phylum                                      0.6
# Class                                       1.2
# Order                                       1.9
# Family                                      3.6
# Genus                                      17.5
# Species                                    42.4
# Higher_taxon                                0.8
# Indication                                  9.4
# Name_status                                 0.0
# Rank                                        0.0
# Diversity_metric_type                       0.0
# Diversity_metric                            0.0
# Diversity_metric_is_effort_sensitive        0.0
# Diversity_metric_is_suitable_for_Chao       0.0
# Diversity_metric_unit                       0.0
# Measurement                                 0.0
# Effort_corrected_measurement                0.0
# Predominant_land_use                        0.0
# Source_for_predominant_land_use             0.7
# Use_intensity                               0.0
# Habitat_as_described                       22.2
# Habitat_patch_area_square_metres           81.6
# Km_to_nearest_edge_of_habitat              84.1
# Years_since_fragmentation_or_conversion    60.6
# dtype: float64

# %% [markdown]
# **Comment:** Good data coverage on most variables we want to use. There is quite a lot of missing data in the lowest levels of the taxonomy (genus and species). Also missing data on linear extent of many sites, which we want to use in the detection model.

# %% [markdown]
# ### Sampling methods

# %%
# Display all sampling methods
set(df_predicts["Sampling_method"].tolist())
# Out:
# {'accoustic encounter transect',
#  'aerial flight-inception  trap',
#  'aerial flight-interception trap',
#  'aerial nets',
#  'aerial transect',
#  'anabat detector',
#  'baited pit-fall traps',
#  'baited sherman traps along transects',
#  'baited traps',
#  'bamboo twigs',
#  'biomass estimation',
#  'bole trap',
#  'call playback',
#  'call surveys',
#  'camera traps',
#  'cylindrical gauze traps',
#  'drift fences with traps',
#  'fall nets under trees',
#  'fern collection',
#  'fixed plots/quadrats',
#  'flight trap',
#  'flower visitation observation',
#  'flower visitations',
#  'fogging',
#  'glue traps',
#  'harp trap',
#  'light trap',
#  'line transect distance sampling',
#  'line/belt transects',
#  'litter and twigs augmented',
#  'litter augmented',
#  'litter collection',
#  'live traps',
#  'mackinnon list survey',
#  'malaise traps',
#  'mist-netting',
#  'mixed trap',
#  'mixed traps',
#  'multiple',
#  'pan traps',
#  'phytometer',
#  'pit-fall traps',
#  'pit-fall traps with drift fences',
#  'pitfall trap transects',
#  'plots/quadrats',
#  'point counts',
#  'quadrats on transects',
#  'random walk',
#  'reporting rates',
#  'small mammal trapping',
#  'soil core',
#  'soil cores along transects',
#  'soil sample',
#  'specimen collection',
#  'suction samplers',
#  'sweep net',
#  'sweep nets',
#  'sweep netting',
#  'sweep path',
#  'sweep_netting',
#  'systematic searching',
#  'transect',
#  'transects with baits',
#  'trap nests',
#  'tunnel trap',
#  'tvsp traps',
#  'various',
#  'visual and disturbance survey',
#  'visual encounter survey',
#  'visual encounter survey and acoustic survey',
#  'window trap',
#  'window traps'}

# %% [markdown]
# ### Number of taxa per site

# %%
# Calculate number of species per unique site (groupby source-study-block-site)
# Taxon_name_entered is the only field that gives the correct count
taxa_per_site = df_predicts.groupby("SSBS")["Taxon_name_entered"].nunique().to_numpy()
print(np.mean(taxa_per_site))
print(np.min(taxa_per_site))
print(np.max(taxa_per_site))
# Out:
# 120.8531452876651
# 1
# 1857

# %% [markdown]
# ### Number of sites per study

# %%
# Calculate number of sites per study
# (groupby source-study, count source-study-block-site)
sites_per_study = df_predicts.groupby("SS")["SSBS"].nunique().to_numpy()
print(np.mean(sites_per_study))
print(np.min(sites_per_study))
print(np.max(sites_per_study))
# Out:
# 43.74051407588739
# 2
# 754

# %% [markdown]
# ### Number of blocks and sites per block

# %%
# Number of studies that contain blocks
num_block_studies = df_predicts[df_predicts["Block"].notnull()]["SS"].nunique()
num_block_studies
# Out:
# 255

# %%
# Calculate number of sites per block, by filtering out studies with no block definitions
# (groupby source-study-block, count source-study-block-site)
sites_per_block = (
    df_predicts[df_predicts["Block"].notnull()]
    .groupby("SSB")["SSBS"]
    .nunique()
    .to_numpy()
)
print(np.mean(sites_per_block))
print(np.min(sites_per_block))
print(np.max(sites_per_block))
# Out:
# 3.997634917222103
# 1
# 148

# %% [markdown]
# ### Land use types and intensities

# %%
set(df_predicts["Predominant_land_use"].tolist())
# Out:
# {'Cannot decide',
#  'Cropland',
#  'Intermediate secondary vegetation',
#  'Mature secondary vegetation',
#  'Pasture',
#  'Plantation forest',
#  'Primary vegetation',
#  'Secondary vegetation (indeterminate age)',
#  'Urban',
#  'Young secondary vegetation'}

# %%
# Percentage of "Cannot decide" land use types
round(
    (
        len(df_predicts[df_predicts["Predominant_land_use"] == "Cannot decide"])
        / len(df_predicts)
    )
    * 100,
    2,
)
# Out:
# 0.19

# %%
set(df_predicts["Use_intensity"].tolist())
# Out:
# {'Cannot decide', 'Intense use', 'Light use', 'Minimal use'}

# %%
# Percentage of "Cannot decide" land use intensities
round(
    (
        len(df_predicts[df_predicts["Use_intensity"] == "Cannot decide"])
        / len(df_predicts)
    )
    * 100,
    2,
)
# Out:
# 9.41

# %% [markdown]
# **Comment:** Can safely drop the "Cannot decide" observations for land use, but for intensity we need to include it as a category.

# %% [markdown]
# ## Functions for plotting

# %%
def plot_frequencies(
    df: pd.DataFrame,
    group_col: str,
    count_type: str,
    title: str,
    sort_ascending: bool = False,
    flip_axes: bool = False,
) -> None:
    """
    Plot frequencies of unique values or counts in a specified column, grouped by another column.

    Args:
        df (pd.DataFrame): Dataframe containing the data for plotting.
        group_col (str): The column name to group by.
        count_type (str): Specifies whether to count 'measurements' or 'unique_values'.
        title (str): The title for the plot.
        sort_ascending (bool): Whether to sort the counts in ascending order. Defaults is to
            sort in descending order.
        flip_axes (bool): Whether to flip the x and y axes. Defaults to False.

    Returns
        None
    """
    assert count_type in [
        "measurements",
        "unique_values",
    ], "count_type must be either 'measurements' or 'unique_values'"

    # Create new dataframe from groupby and unique values or count
    agg_func = "nunique" if count_type == "unique_values" else "count"
    df_counts = (
        df.groupby(group_col)["SSBS"]
        .agg(agg_func)
        .reset_index()
        .rename(columns={"SSBS": "Frequency"})
    )

    # Sort the data according to the specification
    df_counts = df_counts.sort_values("Frequency", ascending=sort_ascending)

    # Set figure style and create figure
    sns.set_style("dark")
    sns.set()
    plt.figure(figsize=(6, 6))

    # Define a formatter function for the labels
    def _number_formatter(value, *args):
        # Check how large the values in the data are
        # If up to 10, use decimal formatting
        max_val = df_counts["Frequency"].max()
        if max_val <= 10:
            return f"{value:.1f}"
        else:
            return f"{value:,.0f}"

    # Create the barplot with the specified orientation
    if flip_axes:
        ax = sns.barplot(data=df_counts, x="Frequency", y=group_col, linewidth=0)
        plt.xlabel("Frequency")
        plt.ylabel(group_col)
        ax.xaxis.set_major_formatter(FuncFormatter(_number_formatter))
    else:
        ax = sns.barplot(data=df_counts, x=group_col, y="Frequency", linewidth=0)
        plt.xlabel(group_col)
        plt.ylabel("Frequency")
        ax.yaxis.set_major_formatter(FuncFormatter(_number_formatter))

    # Add labels to bars and show the plot
    ax.bar_label(ax.containers[0], fmt=_number_formatter, padding=3)
    plt.title(title, fontsize=14)
    plt.show()

# %%
def plot_histogram_with_density(
    df: pd.DataFrame,
    data_col: str,
    title: str,
    xlabel: str,
    bins: int = 50,
    kde: bool = True,
    lower_lim: int = None,
    upper_lim: int = None,
) -> None:
    """
    Plots a histogram with a density overlay for the specified column of a DataFrame.

    Args:
        df (pd.DataFrame): Dataframe containing the data for plotting.
        data_col (str): The name of the column to plot.
        xlabel (str): The label for the x-axis.
        title (str): The title for the plot.
        bins (int): The number of bins to use for the histogram. Defaults to 50.
        kde (bool): Whether to overlay a kernel density estimate. Defaults to True.
        lower_lim (int): Smallest value to display in the plot. Defaults to None.
        upper_lim (int): Largest value to display in the plot. Defaults to None.

    Returns:
        None
    """
    assert data_col in df.columns, "Dataframe must contain data_col"

    # Filter the dataframe for the lower and upper thresholds
    if lower_lim:
        df = df[df[data_col] >= lower_lim]
    if upper_lim:
        df = df[df[data_col] <= upper_lim]

    # Set figure style
    sns.set_style("dark")
    sns.set()

    # Create the histogram
    plt.figure(figsize=(10, 6))
    ax = sns.histplot(df[data_col], bins=bins, kde=kde)

    # Define a formatter function for the labels
    def _number_formatter(value, *args):
        # Check how large the values in the data are
        # If up to 10, use decimal formatting
        max_val = df[data_col].max()
        if max_val <= 10:
            return f"{value:.1f}"
        else:
            return f"{value:,.0f}"

    # Set formatting
    ax.xaxis.set_major_formatter(FuncFormatter(_number_formatter))
    ax.yaxis.set_major_formatter(FuncFormatter(_number_formatter))
    plt.title(title, fontsize=14)
    plt.xlabel(xlabel)
    plt.ylabel("Frequency")

    plt.show()

# %% [markdown]
# ## Diversity metrics
#
# ### Measurements per diversity metric and abundance unit type

# %%
plot_frequencies(
    df_predicts,
    group_col="Diversity_metric_type",
    count_type="measurements",
    title="Number of measurements per type of diversity metric",
    sort_ascending=False,
    flip_axes=False,
)

# %% [markdown]
# ### Filtering of data for rest of analysis
#
# Since both biodiversity metrics (total abundance and compositional similarity) are abundance-based, we filter the dataframe to only contain abundance measurements.

# %%
# Filter dataframe to only include abundance measurements
df_abundance = df_predicts[df_predicts["Diversity_metric_type"] == "Abundance"]

# %%
plot_frequencies(
    df_abundance,
    group_col="Diversity_metric_unit",
    count_type="measurements",
    title="Number of measurements per Abundance diversity unit",
    sort_ascending=False,
    flip_axes=True,
)

# %% [markdown]
# ## Geographic and biogeographic coverage
#
# ### Realms and biomes

# %%
# List all realms
realms = list(set(df_predicts["Realm"]))
print(realms)
# Out:
# ['Afrotropic', 'Oceania', 'Palearctic', 'Indo-Malay', 'Neotropic', 'Australasia', 'Nearctic']

# %%
# List all biomes per realm
for realm in realms:
    biomes = list(set(df_predicts[df_predicts["Realm"] == realm]["Biome"]))
    print(f"{realm}: {biomes}\n")
# Out:
# Afrotropic: ['Deserts & Xeric Shrublands', 'Tropical & Subtropical Grasslands, Savannas & Shrublands', 'Mangroves', 'Mediterranean Forests, Woodlands & Scrub', 'Tropical & Subtropical Moist Broadleaf Forests', 'Montane Grasslands & Shrublands', 'Tropical & Subtropical Dry Broadleaf Forests']
#
# Oceania: ['Tropical & Subtropical Dry Broadleaf Forests', 'Tropical & Subtropical Moist Broadleaf Forests']
#
# Palearctic: ['Deserts & Xeric Shrublands', 'Tundra', 'Temperate Conifer Forests', 'Temperate Grasslands, Savannas & Shrublands', 'Mediterranean Forests, Woodlands & Scrub', 'Temperate Broadleaf & Mixed Forests', 'Montane Grasslands & Shrublands', 'Boreal Forests/Taiga']
#
# Indo-Malay: ['Deserts & Xeric Shrublands', 'Temperate Broadleaf & Mixed Forests', 'Tropical & Subtropical Moist Broadleaf Forests', 'Tropical & Subtropical Dry Broadleaf Forests', 'Montane Grasslands & Shrublands', 'Tropical & Subtropical Coniferous Forests', 'Temperate Conifer Forests']
#
# Neotropic: ['Deserts & Xeric Shrublands', 'Tropical & Subtropical Grasslands, Savannas & Shrublands', 'Mangroves', 'Temperate Grasslands, Savannas & Shrublands', 'Mediterranean Forests, Woodlands & Scrub', 'Flooded Grasslands & Savannas', 'Temperate Broadleaf & Mixed Forests', 'Tropical & Subtropical Moist Broadleaf Forests', 'Tropical & Subtropical Dry Broadleaf Forests', 'Montane Grasslands & Shrublands', 'Tropical & Subtropical Coniferous Forests']
#
# Australasia: ['Deserts & Xeric Shrublands', 'Tropical & Subtropical Grasslands, Savannas & Shrublands', 'Temperate Grasslands, Savannas & Shrublands', 'Mediterranean Forests, Woodlands & Scrub', 'Tropical & Subtropical Moist Broadleaf Forests', 'Montane Grasslands & Shrublands', 'Temperate Broadleaf & Mixed Forests']
#
# Nearctic: ['Deserts & Xeric Shrublands', 'Tropical & Subtropical Grasslands, Savannas & Shrublands', 'Temperate Conifer Forests', 'Temperate Grasslands, Savannas & Shrublands', 'Mediterranean Forests, Woodlands & Scrub', 'Temperate Broadleaf & Mixed Forests', 'Tropical & Subtropical Coniferous Forests', 'Boreal Forests/Taiga']

# %% [markdown]
# ### Sites and measurements per biome

# %%
plot_frequencies(
    df_abundance,
    group_col="Biome",
    count_type="unique_values",
    title="Number of sampling locations per biome",
    sort_ascending=False,
    flip_axes=True,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 plot_frequencies(
# ----> 2     df_abundance,
#       3     group_col="Biome",
#       4     count_type="unique_values",
#       5     title="Number of sampling locations per biome",
#       6     sort_ascending=False,
#       7     flip_axes=True,
#       8 )
#
# NameError: name 'df_abundance' is not defined

# %%
plot_frequencies(
    df_abundance,
    group_col="Biome",
    count_type="measurements",
    title="Number of measurements per biome",
    sort_ascending=False,
    flip_axes=True,
)

# %% [markdown]
# ### Sites and measurements per UN subregion

# %%
plot_frequencies(
    df_abundance,
    group_col="UN_subregion",
    count_type="unique_values",
    title="Number of sampling locations per UN subregion",
    sort_ascending=False,
    flip_axes=True,
)

# %%
plot_frequencies(
    df_abundance,
    group_col="UN_subregion",
    count_type="measurements",
    title="Number of measurements per UN subregion",
    sort_ascending=False,
    flip_axes=True,
)

# %% [markdown]
# ## Land use coverage
#
# ### Sites and measurements per land-use type and intensity

# %%
plot_frequencies(
    df_abundance,
    group_col="Predominant_land_use",
    count_type="unique_values",
    title="Number of sampling locations per land-use type",
    sort_ascending=False,
    flip_axes=True,
)

# %%
plot_frequencies(
    df_abundance,
    group_col="Predominant_land_use",
    count_type="measurements",
    title="Number of measurements per land-use type",
    sort_ascending=False,
    flip_axes=True,
)

# %%
# Create land use type x intensity combinations
df_abundance = df_abundance.copy()
df_abundance["Land_use_type_intensity"] = df_abundance.apply(
    lambda x: f"{x['Predominant_land_use']} x {x['Use_intensity']}", axis=1
)

# %%
plot_frequencies(
    df_abundance,
    group_col="Land_use_type_intensity",
    count_type="unique_values",
    title="Number of sampling locations per land-use type x intensity combination",
    sort_ascending=False,
    flip_axes=True,
)

# %%
plot_frequencies(
    df_abundance,
    group_col="Land_use_type_intensity",
    count_type="measurements",
    title="Number of measurements per land-use type x intensity combination",
    sort_ascending=False,
    flip_axes=True,
)

# %% [markdown]
# ## Taxonomic coverage
#
# ### Measurements per Kingdom

# %%
plot_frequencies(
    df_abundance,
    group_col="Kingdom",
    count_type="measurements",
    title="Number of measurements per Kingdom",
    sort_ascending=False,
    flip_axes=False,
)

# %%
df_abundance.loc[df_abundance["Kingdom"] == "Animalia"]["Phylum"].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_abundance.loc[df_abundance["Kingdom"] == "Animalia"]["Phylum"].unique()
#
# NameError: name 'df_abundance' is not defined

# %% [markdown]
# ### Measurements per Phylum

# %%
plot_frequencies(
    df_predicts,
    group_col="Phylum",
    count_type="measurements",
    title="Number of measurements per Phylum",
    sort_ascending=False,
    flip_axes=True,
)

# %% [markdown]
# ### Measurements per Class

# %%
df_class_obs = df_predicts.groupby("Class")["Measurement"].count().reset_index()

plot_histogram_with_density(
    df_class_obs,
    data_col="Measurement",
    title="Number of measurements per Class, binned",
    xlabel="Bins",
    bins=50,
    kde=False,
    lower_lim=None,
    upper_lim=None,
)
# Out:
# /Users/jakobnystrom/anaconda3/envs/biodiv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df_class_obs = df_predicts.groupby("Class")["Measurement"].count().reset_index()

plot_histogram_with_density(
    df_class_obs,
    data_col="Measurement",
    title="Number of measurements per Class, binned (range 0-20,000)",
    xlabel="Bins",
    bins=50,
    kde=False,
    lower_lim=None,
    upper_lim=20000,
)
# Out:
# /Users/jakobnystrom/anaconda3/envs/biodiv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Measurements per Order

# %%
df_order_obs = df_predicts.groupby("Order")["Measurement"].count().reset_index()

plot_histogram_with_density(
    df_order_obs,
    data_col="Measurement",
    title="Number of measurements per Order, binned (range 0-20,000)",
    xlabel="Bins",
    bins=50,
    kde=False,
    lower_lim=None,
    upper_lim=20000,
)
# Out:
# /Users/jakobnystrom/anaconda3/envs/biodiv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Measurements per Family

# %%
df_family_obs = df_predicts.groupby("Family")["Measurement"].count().reset_index()

plot_histogram_with_density(
    df_family_obs,
    data_col="Measurement",
    title="Number of measurements per Family, binned (range 0-20,000)",
    xlabel="Bins",
    bins=50,
    kde=False,
    lower_lim=None,
    upper_lim=20000,
)
# Out:
# /Users/jakobnystrom/anaconda3/envs/biodiv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Deep dive: Sites and measurements for amphibians in Americas

# %%
# Filter dataframe for Americas and amphibians
df_americas_amph = df_abundance.loc[
    (df_predicts["UN_region"] == "Americas") & (df_predicts["Class"] == "Amphibia")
]

# %%
plot_frequencies(
    df_americas_amph,
    group_col="Order",
    count_type="unique_values",
    title="Number of sampling locations per Order for (Americas, Amphibia)",
    sort_ascending=False,
    flip_axes=False,
)

# %%
plot_frequencies(
    df_americas_amph,
    group_col="Order",
    count_type="measurements",
    title="Number of measurements per Order for Americas, Amphibia",
    sort_ascending=False,
    flip_axes=False,
)

# %% [markdown]
# ## Distribution of abundance data
#
# We use effort corrected measurement data, to get as close as possible to true abundance with the data we have. We also drop cases where land use type is unknown.

# %%
# Drop entries where land use type is unknown
df_abundance = df_abundance.dropna(subset=["Predominant_land_use"])

# %% [markdown]
# ### Individual count data

# %%
# Filter dataframe to only include abundance given as count of individuals
df_abund_ind = df_abundance[df_abundance["Diversity_metric_unit"] == "individuals"]

# %%
# Check some summary statistics of the data
stats = ["mean", "median", "min", "max", "std"]
df_abund_ind["Effort_corrected_measurement"].agg(stats)
# Out:
# mean          23.286306
# median         0.000000
# min            0.000000
# max       394656.000000
# std          575.712881
# Name: Effort_corrected_measurement, dtype: float64

# %%
# Do the same analysis, but averaged across sites
df_agg_stats = (
    df_abund_ind.groupby("SSBS")["Effort_corrected_measurement"]
    .agg(stats)
    .reset_index()
)
df_agg_stats.drop("SSBS", axis="columns").mean()
# Out:
# mean       17.585171
# median      1.519691
# min         1.256337
# max       842.852137
# std        85.708034
# dtype: float64

# %% [markdown]
# ### Log transformed count of individuals

# %%
# Calculate total abundance for each site
df_ind_count_per_site = (
    df_abund_ind.groupby("SSBS")["Effort_corrected_measurement"]
    .sum()
    .reset_index()
    .rename(columns={"Effort_corrected_measurement": "Tot_abundance"})
)

# Do log(x + 1) transformation of abundance numbers
df_ind_count_log = df_ind_count_per_site.copy()
df_ind_count_log.loc[:, "Tot_abundance_log"] = np.log(
    df_ind_count_log["Tot_abundance"] + 1
)

# %%
plot_histogram_with_density(
    df_ind_count_log,
    data_col="Tot_abundance_log",
    title="EDF of individual counts per site (log)",
    xlabel="Binned count of individuals, log (x + 1) transformed (site level)",
    bins=50,
    kde=True,
)
# Out:
# /Users/jakobnystrom/anaconda3/envs/biodiv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Comment:** The log transformed count data follows a complex, multimodal distribution with three peaks: at zero, around 3 and around 11. The two density peaks at 3 and 11 can indicate differences in the taxonomic focus of different studies (with frequent and rarer species).

# %% [markdown]
# ### Capped count of individuals

# %%
# Perform similar analysis, but instead of log transform, filter out large values
upper_lim = 100

# Filter data for upper limit
df_ind_count_lim = df_ind_count_per_site[
    df_ind_count_per_site["Tot_abundance"] <= upper_lim
]

# %%
plot_histogram_with_density(
    df_ind_count_lim,
    data_col="Tot_abundance",
    title="EDF of individual counts per site (capped)",
    xlabel=f"Binned count of individuals, capped at {upper_lim} (site level)",
    bins=50,
    kde=True,
)
# Out:
# /Users/jakobnystrom/anaconda3/envs/biodiv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Comment:** Untransformed count data is approx Poisson, but possibly with a higher frequency of zeros than the standard model would assume.

# %% [markdown]
# ### Abundance data dispersion

# %%
# Calculate std-mean ratio
df_agg_stats_dropna = df_agg_stats.dropna(subset=["mean", "std"]).copy()
df_agg_stats_dropna["Std_mean_ratio"] = (
    df_agg_stats_dropna["std"] / df_agg_stats_dropna["mean"]
)

# %%
plot_histogram_with_density(
    df_agg_stats_dropna,
    data_col="Std_mean_ratio",
    title="EDF of standard deviation-mean ratios",
    xlabel="Stddev-mean ratio (site level)",
    bins=50,
    kde=True,
)
# Out:
# /Users/jakobnystrom/anaconda3/envs/biodiv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Comment:** If we compare to a Poisson model, which assumes equal mean and variance, the data is highly overdispersed. That would speak in favor for using a Negative-Binomial distribution for count data. Still there are a few instances where data is underdispersed.

# %% [markdown]
# ### 0-1 scaled abundance data
#
# This includes all abundance measurements, not just the ones reported as counts of individuals.

# %%
# Calculate the total abundance for each site, grouped by study
df_study_site_abund = df_abundance.copy()
df_study_site_abund = (
    df_study_site_abund.groupby(["SS", "SSBS"])["Effort_corrected_measurement"]
    .sum()
    .reset_index()
    .rename(columns={"Effort_corrected_measurement": "Site_abundance"})
)

# %%
# Calculate the max and min total abundance within each study
df_study_min_max = (
    (df_study_site_abund.groupby("SS")["Site_abundance"].agg(["min", "max"]))
    .reset_index()
    .rename(columns={"min": "Min_abundance", "max": "Max_abundance"})
)

# %%
# Join the first and second dataframes on study
df_study_site_scaled = df_study_site_abund.join(
    df_study_min_max.set_index("SS"), on="SS", how="left", validate="m:1"
)

# %%
# Perform min-max scaling of site-level abundance
abund = df_study_site_scaled["Site_abundance"]
min_abund = df_study_site_scaled["Min_abundance"]
max_abund = df_study_site_scaled["Max_abundance"]
df_study_site_scaled["Abundance_scaled"] = (abund - min_abund) / (max_abund - min_abund)

# %% [markdown]
# ### Distribution with standard min-max scaling

# %%
plot_histogram_with_density(
    df_study_site_scaled,
    data_col="Abundance_scaled",
    title="Empirical distribution function (EDF) of scaled abundance",
    xlabel="Binned min-max (0-1) scaled abundance (site level)",
    bins=100,
    kde=True,
)
# Out:
# /Users/jakobnystrom/anaconda3/envs/biodiv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Distribution of abundance / max(abundances in study)

# %%
# The BII authors don't do min-max scaling, they do abundance / max_abundance
df_study_site_scaled["Abundance_scaled_BII"] = abund / max_abund

plot_histogram_with_density(
    df_study_site_scaled,
    data_col="Abundance_scaled_BII",
    title="Empirical distribution function (EDF) of scaled abundance",
    xlabel="Binned scaled abundance (0-1), site / study max (site level)",
    bins=100,
    kde=True,
)
# Out:
# /Users/jakobnystrom/anaconda3/envs/biodiv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Comment:** This should be possible to approximate with a zero-one inflated Beta regression. The BII version is less zero-inflated than using min-max scaling, which could be a benefit. The analysis below is based on this measure.

# %%
# Check percentage of exact 0s and 1s in the data
total_obs = len(df_study_site_scaled)
min_max_zeros = (
    len(df_study_site_scaled.loc[df_study_site_scaled["Abundance_scaled"] == 0])
    / total_obs
)
print(min_max_zeros)
min_max_ones = (
    len(df_study_site_scaled.loc[df_study_site_scaled["Abundance_scaled"] == 1])
    / total_obs
)
print(min_max_ones)
max_zeros = (
    len(df_study_site_scaled.loc[df_study_site_scaled["Abundance_scaled_BII"] == 0])
    / total_obs
)
print(max_zeros)
max_ones = (
    len(df_study_site_scaled.loc[df_study_site_scaled["Abundance_scaled_BII"] == 1])
    / total_obs
)
print(max_ones)
# Out:
# 0.06904202977779207
# 0.024536128887030904
# 0.04334823294851593
# 0.024536128887030904

# %% [markdown]
# ### Transformation of the scaled abundance
#
# The authors of BII apply a square-root transformation to the scaled data, then assume that residuals are Gaussian. They also tried a log transformation. We compare both approaches below.

# %%
# Do square-root transformation of the scaled data
df_study_site_scaled["Scaled_abund_sqrt"] = np.sqrt(
    df_study_site_scaled["Abundance_scaled_BII"]
)

# %%
plot_histogram_with_density(
    df_study_site_scaled,
    data_col="Scaled_abund_sqrt",
    title="Empirical distribution function (EDF) of scaled abundance",
    xlabel="Binned scaled abundance, square-root transformed (site level)",
    bins=100,
    kde=True,
)
# Out:
# /Users/jakobnystrom/anaconda3/envs/biodiv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Comment:** This could be approximated with a zero-one inflated Beta or logit-Normal distribution. While a transformation on top of a transformation might not be ideal, we can try if sqrt improves the model fit and predictions.

# %%
# Do log transformation of the scaled data
df_study_site_scaled["Scaled_abund_log"] = np.log(
    df_study_site_scaled["Abundance_scaled_BII"] + 1
)

# %%
plot_histogram_with_density(
    df_study_site_scaled,
    data_col="Scaled_abund_log",
    title="Empirical distribution function (EDF) of scaled abundance",
    xlabel="Max scaled abundance, log (x + 1) transformed",
    bins=100,
    kde=True,
)
# Out:
# /Users/jakobnystrom/anaconda3/envs/biodiv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Do logit transformation of the scaled data


def logit(abund):
    adjust = 0.001

    if abund == 0:
        res = scipy.special.logit(abund + adjust)
    elif abund == 1:
        res = scipy.special.logit(abund - adjust)
    else:
        res = scipy.special.logit(abund - adjust)

    return res

# %%
df_study_site_scaled = df_study_site_scaled.copy()
df_study_site_scaled["Scaled_abund_logit"] = df_study_site_scaled[
    "Abundance_scaled_BII"
].apply(lambda row: logit(row))

# %%
plot_histogram_with_density(
    df_study_site_scaled,
    data_col="Scaled_abund_logit",
    title="Empirical distribution function (EDF) of scaled abundance",
    xlabel="Max scaled abundance, logit transformed",
    bins=100,
    kde=True,
)
# Out:
# /Users/jakobnystrom/anaconda3/envs/biodiv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Alternative scaling approach: Average scaling
#
# To avoid the inflation of ones, we divide each abundance with the within-study average.

# %%
# Calculate the max and min total abundance within each study
df_study_mean = (
    df_study_site_abund.groupby("SS")["Site_abundance"]
    .mean()
    .reset_index()
    .rename(columns={"Site_abundance": "Mean_abundance"})
)

# %%
# Join the new column to the existing dataframe
df_study_site_scaled = df_study_site_scaled.join(
    df_study_mean.set_index("SS"), on="SS", how="left", validate="m:1"
)

# Calculate the new scaled numbers
df_study_site_scaled["Abundance_scaled_mean"] = (
    abund / df_study_site_scaled["Mean_abundance"]
)

# %%
plot_histogram_with_density(
    df_study_site_scaled,
    data_col="Abundance_scaled_mean",
    title="Empirical distribution function (EDF) of scaled abundance",
    xlabel="Binned scaled abundance, site / study average (site level)",
    bins=100,
    kde=True,
)
# Out:
# /Users/jakobnystrom/anaconda3/envs/biodiv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Transformations of the average-scaled data

# %%
df_study_site_scaled = df_study_site_scaled.copy()

# Log
df_study_site_scaled["Scaled_abund_mean_log"] = np.log(
    df_study_site_scaled["Abundance_scaled_mean"] + 1
)

# Square-root
df_study_site_scaled = df_study_site_scaled.copy()
df_study_site_scaled["Scaled_abund_mean_sqrt"] = np.sqrt(
    df_study_site_scaled["Abundance_scaled_mean"]
)
# Cube-root
df_study_site_scaled = df_study_site_scaled.copy()
df_study_site_scaled["Scaled_abund_mean_cbrt"] = np.cbrt(
    df_study_site_scaled["Abundance_scaled_mean"]
)

# %%
plot_histogram_with_density(
    df_study_site_scaled,
    data_col="Scaled_abund_mean_log",
    title="Empirical distribution function (EDF) of scaled abundance",
    xlabel="Mean-scaled abundance, log (x + 1) transformed",
    bins=100,
    kde=True,
)
# Out:
# /Users/jakobnystrom/anaconda3/envs/biodiv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plot_histogram_with_density(
    df_study_site_scaled,
    data_col="Scaled_abund_mean_sqrt",
    title="Empirical distribution function (EDF) of scaled abundance",
    xlabel="Mean-scaled abundance, square-root transformed",
    bins=100,
    kde=True,
)
# Out:
# /Users/jakobnystrom/anaconda3/envs/biodiv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plot_histogram_with_density(
    df_study_site_scaled,
    data_col="Scaled_abund_mean_cbrt",
    title="Empirical distribution function (EDF) of scaled abundance",
    xlabel="Mean-scaled abundance, cube-root transformed",
    bins=100,
    kde=True,
)
# Out:
# /Users/jakobnystrom/anaconda3/envs/biodiv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Distribution of compositional similarity

# %%
# Load the complete data set, this time using polars
df_predicts = pl.read_csv("../../data/PREDICTS/merged_data.csv")

# %%
df_abundance = df_predicts.filter(pl.col("Diversity_metric_type") == "Abundance")

# %%
# Identify studies with consistent sampling effort across sites
single_effort_studies = (
    df_abundance.group_by("SS")
    .agg(pl.col("Sampling_effort").n_unique().alias("unique_effort"))
    .filter(pl.col("unique_effort") == 1)
    .get_column("SS")
    .to_list()
)

# %%
# Identify studies where at least one site is minimally-used primary vegetation
min_primary_studies = (
    df_abundance.filter(
        (pl.col("Predominant_land_use") == "Primary vegetation")
        & (pl.col("Use_intensity") == "Minimal use")
    )
    .get_column("SS")
    .unique()
    .to_list()
)

# %%
# Identify studies with more than one taxon surveyed
multi_taxa_studies = (
    df_abundance.group_by("SS")
    .agg(pl.col("Taxon_name_entered").n_unique().alias("unique_taxon"))
    .filter(pl.col("unique_taxon") > 1)
    .get_column("SS")
    .unique()
    .to_list()
)

# %%
# Filter the original dataframe for all of these criteria
studies_to_include = list(
    set(single_effort_studies) & set(min_primary_studies) & set(multi_taxa_studies)
)
df_similarity_calc = df_abundance.filter(pl.col("SS").is_in(studies_to_include))
len(studies_to_include)
# Out:
# 244

# %%
# List of all studies, and list for storing results
studies = df_similarity_calc.get_column("SS").unique().to_list()
results = []

start = time.time()

# Iterate through all studies
for study in studies:
    df_study = df_similarity_calc.filter((pl.col("SS") == study)).lazy()
    results = pairwise_similarity_scores(study, df_study, results)

end = time.time()
print(end - start)

# Create a dataframe from the output of all site pairs
df_comp_similarity = pl.DataFrame(results)
# Out:
# 968.3015460968018

# %%
df_comp_similarity.shape
# Out:
# (586660, 4)

# %%
def pairwise_similarity_scores(study, df, results):

    # Get a list of all minimal-primary sites
    min_primary_sites = (
        df.filter(
            (pl.col("Predominant_land_use") == "Primary vegetation")
            & (pl.col("Use_intensity") == "Minimal use")
        )
        .collect()
        .get_column("SSBS")
        .unique()
        .to_list()
    )
    # Then get a list of all the sites
    all_sites = df.collect().get_column("SSBS").unique().to_list()

    # Apply the Bray-Curtis function to every pair of sites
    for site_1 in min_primary_sites:
        for site_2 in all_sites:
            if site_1 != site_2:
                score = calculate_bray_curtis(df, study, site_1, site_2)
                results.append(score)
            else:
                continue

    return results

# %%
def calculate_bray_curtis(
    df: pd.DataFrame, study: str, site_1: str, site_2: str
) -> dict:
    """
    Calculate the Bray-Curtis similarity metric between a pair of sites
    from the same study.

    Args:
        df (pd.DataFrame): Dataframe filtered for the study in question.
        study (str): The study being evaluated.
        site_1 (str): A minimally-used primary vegation site from the study.
        site_2 (str): Any other site in that study.

    Returns
        bray_curtis_output (dict): Dictionary with the Bray-Curtis score of
        the two sites, and IDs for the study and sites.
    """

    # Create two dataframes with required information about both sites
    # Since sampling effort is consistent, we use raw Measurement
    df_site_1 = (
        df.filter(pl.col("SSBS") == site_1)
        .select(["SSBS", "Taxon_name_entered", "Measurement"])
        .sort("Taxon_name_entered")
        .collect()
    )
    df_site_2 = (
        df.filter(pl.col("SSBS") == site_2)
        .select(["SSBS", "Taxon_name_entered", "Measurement"])
        .sort("Taxon_name_entered")
        .collect()
    )

    # Calculate the total abundance of each site
    s1_tot_abund = df_site_1.get_column("Measurement").sum()
    s2_tot_abund = df_site_2.get_column("Measurement").sum()

    # Handle cases where one or both sites have zero abundance
    if s1_tot_abund == 0 and s2_tot_abund == 0:
        bray_curtis = np.nan
    elif s1_tot_abund == 0 or s2_tot_abund == 0:
        bray_curtis = 0

    # Case where both sites have abundance values
    else:
        # Get lists of taxons for each site
        s1_taxa = df_site_1.get_column("Taxon_name_entered").to_list()
        s2_taxa = df_site_2.get_column("Taxon_name_entered").to_list()

        # Check if the list of taxons are identical
        # Then we can directly convert measurements to a numpy array
        if set(s1_taxa) == set(s2_taxa) and len(df_site_1) == len(df_site_2):
            pairwise_abundance = np.column_stack(
                (
                    df_site_1.get_column("Measurement"),
                    df_site_2.get_column("Measurement"),
                )
            )

        # Otherwise we need to do a merge of dataframes first
        else:
            # Do an outer merge on taxon name and fill any non-overlapping taxons with zeros
            df_merged = df_site_1.join(
                df_site_2,
                on="Taxon_name_entered",
                how="outer",
                suffix="_site2",
            )
            df_merged = df_merged.fill_nan(0)

            # Covert to numpy array
            pairwise_abundance = np.column_stack(
                (
                    df_merged.get_column("Measurement"),
                    df_merged.get_column("Measurement_site2"),
                ),
            )

        # Calculate the sum of pair-wise minimum abundance
        min_abundance_sum = np.sum(np.min(pairwise_abundance, axis=1))

        # Calculate the similarity version of the Bray-Curtis dissimilarity metric
        # A value of 1 means that the two sites are identical in composition
        bray_curtis = (2 * min_abundance_sum) / (s1_tot_abund + s2_tot_abund)

    # Create and output dictionary
    bray_curtis_output = {
        "SS": study,
        "Primary_minimal_site": site_1,
        "Other_site": site_2,
        "Similarity_score": bray_curtis,
    }

    return bray_curtis_output

# %%
plot_histogram_with_density(
    df_comp_similarity,
    data_col="Similarity_score",
    title="EDF of compositional similarity",
    xlabel="Compositional similarity (Bray-Curtis, site-site level)",
    bins=100,
    kde=True,
)
# Out:
# /Users/jakobnystrom/anaconda3/envs/biodiv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Do a square-root transformation of the similarity scores
df_comp_similarity = df_comp_similarity.with_columns(
    np.sqrt(pl.col("Similarity_score")).alias("Similarity_score_sqrt")
)

plot_histogram_with_density(
    df_comp_similarity,
    data_col="Similarity_score_sqrt",
    title="EDF of square-root compositional similarity",
    xlabel="Compositional similarity (Bray-Curtis) square-root transformed (site level)",
    bins=100,
    kde=True,
)
# Out:
# /Users/jakobnystrom/anaconda3/envs/biodiv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# **Comment**: Similar distribution as abundance, except that there is not one-inflation.
#
# The BII authors actually used a logit transformation of the compositional similarity, which we try below.

# %%
df_comp_similarity = df_comp_similarity.drop("Similarity_score_logit")

# %%
# Do a logit transformation of the similarity scores
df_comp_similarity = df_comp_similarity.with_columns(
    pl.col("Similarity_score")
    .map_elements(lambda x: logit(x))
    .alias("Similarity_score_logit")
)

# %%
plot_histogram_with_density(
    df_comp_similarity,
    data_col="Similarity_score_logit",
    title="EDF of logit compositional similarity",
    xlabel="Compositional similarity (Bray-Curtis) logit transformed (site level)",
    bins=100,
    kde=True,
)
# Out:
# /Users/jakobnystrom/anaconda3/envs/biodiv/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Sampling time periods

# %%
# Make a copy of the abundance dataframe
df_dates = df_abundance.clone()

# Convert to datetime format
df_dates = df_dates.with_columns(pl.col("Sample_midpoint").str.to_datetime("%Y-%m-%d"))

# Extract the year information
df_dates = df_dates.with_columns(
    pl.col("Sample_midpoint").dt.year().alias("Sample_year")
)

# Count the number of sites sampled per year
yearly_count = df_dates.group_by("Sample_year").agg(
    pl.col("SSBS").n_unique().alias("Site_count")
)

# %%
# Plot the results
sns.set_style("dark")
sns.set()
ax = sns.barplot(data=yearly_count.to_pandas(), x="Sample_year", y="Site_count")
ax.xaxis.set_major_locator(MaxNLocator(nbins=5))
plt.title("Number of sites sampled per year")
plt.show()

# %%
df_predicts.filter(pl.col("Source_ID") == "YY1_2015__Mandle").select(
    "Diversity_metric_unit"
).unique()
# Out:
# shape: (3, 1)
# ┌───────────────────────┐
# │ Diversity_metric_unit │
# │ ---                   │
# │ str                   │
# ╞═══════════════════════╡
# │ percentage            │
# │ individuals           │
# │ presence/absence      │
# └───────────────────────┘

# %%
df_predicts.filter(pl.col("Source_ID") == "YY1_2015__Mandle").select(
    "Sampling_method"
).unique()
# Out:
# shape: (1, 1)
# ┌──────────────────────┐
# │ Sampling_method      │
# │ ---                  │
# │ str                  │
# ╞══════════════════════╡
# │ fixed plots/quadrats │
# └──────────────────────┘

# %%
mandle = (
    df_predicts.filter(pl.col("Source_ID") == "YY1_2015__Mandle")
    .group_by("SS")
    .agg(pl.col("Taxon_name_entered").unique())
)

# %%
mandle.select("Taxon_name_entered")[0]
# Out:
# shape: (1, 1)
# ┌───────────────────────────────────┐
# │ Taxon_name_entered                │
# │ ---                               │
# │ list[str]                         │
# ╞═══════════════════════════════════╡
# │ ["Diospyros montana", "Bridelia … │
# └───────────────────────────────────┘
